# %% [markdown]
# # 💰 Problema 12: Cálculo del Valor Esperado usando el Estimator
#
# El objetivo de cualquier Algoritmo Cuántico Variacional (VQE, QAOA) es encontrar el conjunto de parámetros del Ansatz ($\theta$) que minimiza el Valor Esperado de un observable del sistema (el Hamiltoniano, H).
#
# $$\langle H \rangle = \langle \psi(\boldsymbol{\theta}) | H |\psi ( \boldsymbol{\theta})\rangle$$
#
# La Primitiva `Estimator` (Estimador) es la herramienta dedicada de Qiskit para calcular eficientemente este valor en una computadora cuántica o simulador.
#
# ## 🎯 Objetivo
#
# Entender la tarea fundamental de todos los algoritmos variacionales: calcular el valor esperado $\langle H \rangle$, donde H es el observable, usando explícitamente la Primitiva `Estimator`.
#
# ## 💻 Tarea Central: Calculando $\langle H \rangle$
#
# Se te proporciona un Ansatz de 2 qubits con parámetros fijos y pre-optimizados, y un observable Hamiltoniano (H) simple. Tu tarea es cargar estos componentes y ejecutarlos usando la primitiva `Estimator` para obtener el valor esperado.
#
# ### Requisitos:
#
# 1.  **Definir Ansatz:** Crea el circuito Ansatz de 2 qubits con los parámetros fijos proporcionados.
# 2.  **Definir Observable:** Define el observable H usando la clase `SparsePauliOp` de Qiskit.
# 3.  **Ejecutar Estimator:** Ejecuta el circuito parametrizado y el observable definido usando la Primitiva `Estimator`.
# 4.  **Verificar Resultado:** Imprime el valor esperado final calculado, que representa la "energía" estimada del estado cuántico definido por el Ansatz.
#
# ### Ansatz y Hamiltoniano Proporcionados
#
# | Componente | Definición | Notas |
# | :--- | :--- | :--- |
# | **Ansatz (VQC)** | 2 qubits, tres capas repetidas | $R_y(\theta_0) \otimes R_y(\theta_1) \cdot \mathbf{CX}_{0,1}$ |
# | **Parámetros ($\vec{\theta}$)** | Valores fijos | $\boldsymbol{\theta}=[0.5, 1.2, 0.8, 2.1, 1.5, 0.3]$ |
# | **Hamiltoniano ($\boldsymbol{H}$)** | Observable de 2 qubits | $\boldsymbol{H} = 0.5 \cdot (\boldsymbol{Z}_0 \otimes \boldsymbol{Z}_1) + 1.0 \cdot (\boldsymbol{X}_0 \otimes \boldsymbol{I}_1)$ |
#
# # Solución:

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install qiskit-machine-learning --upgrade
# !pip install qiskit_algorithms

# %%
from qiskit.circuit import QuantumCircuit, Parameter
from qiskit_aer.primitives import Estimator # Importación correcta para el simulador local
from qiskit.quantum_info import SparsePauliOp
import numpy as np

# YOUR CODE HERE
raise NotImplementedError()

# --- 4. Verificación de Resultados ---
print("\n--- Resultado del Estimator ---")
print(f"Valor Esperado Final <H>: {expectation_value:.6f}")
