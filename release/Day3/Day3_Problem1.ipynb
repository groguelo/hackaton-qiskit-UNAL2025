# %% [markdown]
# # 📐 Problema 11: Diseño de Ansatz Parametrizado Personalizado
#
# El poder de un Algoritmo Cuántico Variacional (VQE, QAOA) reside en su Ansatz (o "Feature Map"): un circuito cuántico parametrizado cuya estructura es fija, pero cuyos ángulos de rotación ($\theta_i$) son ajustados iterativamente por un optimizador clásico. Diseñar un Ansatz efectivo es la habilidad central en la computación cuántica híbrida.
#
# ## 🎯 Objetivo
#
# Dominar la construcción de Circuitos Cuánticos Variacionales (VQC) mediante la creación de una estructura profunda, reutilizable y parametrizada, que es el componente central tanto de VQE como de los métodos de Kernel Cuántico.
#
# ## 💻 Tarea Central: Construyendo un Ansatz de Múltiples Capas
#
# Diseña un circuito parametrizado de 4 qubits usando los objetos simbólicos `Parameter` de Qiskit. El circuito debe construirse repitiendo una estructura de bloque fija N=3 veces.
#
# ### Estructura del Bloque (Repetir N=3 veces):
# 1.  **Capa de Codificación de Datos:** Una capa de compuertas $R_y(\theta_i)$, donde cada ángulo de rotación $\theta_i$ es un parámetro simbólico único y recién definido.
# 2.  **Capa de Entrelazamiento:** Una capa de compuertas CNOT que establece un entrelazamiento lineal (un patrón de conexión "nearest-neighbor" o vecino más cercano, ej: $q_0 \to q_1, q_1 \to q_2, q_2 \to q_3$).
#
# ### Requisitos:
# 1.  **Parámetros Simbólicos:** Usa la clase `Parameter` de Qiskit (ej: `theta_0, theta_1, ...`) para definir todos los ángulos de rotación.
# 2.  **Composición del Circuito:** Construye un `QuantumCircuit` llamado `ansatz_circuit`. Usa bucles y `QuantumCircuit.compose()` o un enfoque modular similar para repetir la estructura del bloque 3 veces.
# 3.  **Conteo de Parámetros:** El circuito final debe contener 4 qubits × 3 capas = 12 parámetros de rotación distintos y sin asignar.
#
# # Solución:

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install qiskit-machine-learning --upgrade
# !pip install qiskit_algorithms

# %%
from qiskit.circuit import QuantumCircuit, Parameter, QuantumRegister

# YOUR CODE HERE
raise NotImplementedError()

# --- Ejecución y Verificación ---
NUM_Q = 4
NUM_L = 3
ansatz, parameters = create_custom_ansatz(NUM_Q, NUM_L)

print("Ansatz Parametrizado Final:")
print(ansatz.draw('text', fold=-1))

# --- Verificación de Éxito ---
expected_params = NUM_Q * NUM_L
actual_params = len(ansatz.parameters)

print(f"\nNúmero Total de Parámetros: {actual_params}")

if actual_params == expected_params:
    print(f"✅ ¡Éxito! El circuito tiene los {expected_params} parámetros distintos requeridos.")
else:
    print(f"❌ Error: Se esperaban {expected_params} parámetros, se encontraron {actual_params}.")
