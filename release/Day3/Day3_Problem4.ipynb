# %% [markdown]
# # ⚙️ Problema 14: Clasificación Cuántica de Vectores de Soporte (QSVC) de Extremo a Extremo
#
# Has dominado los dos componentes centrales del Aprendizaje Automático Cuántico (QML): diseñar un Mapa de Características ($\phi(x)$) y calcular el Kernel Cuántico (K). Ahora, combinarás estos para implementar un clasificador binario completo.
#
# El Clasificador Cuántico de Vectores de Soporte (QSVC) reemplaza el kernel RBF tradicional en una Máquina de Vectores de Soporte (SVM) clásica con la similitud no lineal y de alta dimensión medida por el Kernel Cuántico.
#
# ## 🎯 Objetivo
#
# Implementar un flujo de trabajo completo de Aprendizaje Automático Cuántico (QML) de extremo a extremo para clasificación binaria, demostrando la integración de los métodos de kernel de Qiskit con las bibliotecas clásicas de machine learning (a través de `qiskit_machine_learning`).
#
# ## 💻 Tarea Central: Entrenando y Evaluando QSVC
#
# Tu tarea es cargar un conjunto de datos de clasificación estándar de 2 qubits, definir un kernel cuántico adecuado, y usarlo para entrenar y evaluar el algoritmo QSVC.
#
# ### Requisitos:
#
# 1.  **Carga de Datos:** Carga el conjunto de datos de clasificación estándar `ad_hoc_data` de 2 qubits proporcionado por Qiskit Machine Learning.
# 2.  **Definición del Kernel Cuántico:** Define un `QuantumKernel` usando el `ZZFeatureMap` estándar (2 qubits, 2 repeticiones, entrelazamiento lineal).
# 3.  **Instanciación del Modelo:** Instancia la clase `QSVC`, pasándole tu instancia de kernel cuántico definida.
# 4.  **Entrenamiento y Predicción:** Ajusta ("fit") el modelo a los datos de entrenamiento y calcula la precisión (accuracy) de la clasificación en el conjunto de prueba.
#
# # Solución:

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install qiskit-machine-learning --upgrade
# !pip install qiskit_algorithms

# %%
# Importaciones Requeridas
from qiskit_machine_learning.datasets import ad_hoc_data
from qiskit_aer.primitives import Sampler
from qiskit.circuit.library import ZZFeatureMap
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit_machine_learning.algorithms import QSVC
from sklearn.metrics import accuracy_score
import numpy as np
import time

# YOUR CODE HERE
raise NotImplementedError()

# --- Verificación de Rendimiento ---
print("\n--- Rendimiento de QSVC ---")
print(f"Precisión (Accuracy) en Test: {accuracy * 100:.2f}%")
