# %% [markdown]
# # 📊 Problema 15: Optimización del Alineamiento del Kernel Cuántico
#
# En el Problema 14, usaste un `ZZFeatureMap` fijo. Sin embargo, el rendimiento de un Kernel Cuántico depende en gran medida de sus parámetros internos del circuito (ej: los valores $\theta_i$ en un mapa de características parametrizado). Elegir buenos parámetros es esencial.
#
# El `QuantumKernelTrainer` (Entrenador de Kernel Cuántico) usa una métrica clásica, el "Alineamiento del Kernel" (Kernel Alignment), para ajustar iterativamente los parámetros del mapa de características ($\theta$) y hacer que la matriz del kernel cuántico $K$ coincida con la matriz del kernel objetivo ideal $K_{\text{target}}$ (que se deriva de las etiquetas verdaderas de los datos $y$). Maximizar el alineamiento significa maximizar la capacidad del kernel para distinguir entre clases.
#
# ## 🎯 Objetivo
#
# Introducir el concepto avanzado de optimizar la estructura del circuito cuántico (hiperparámetros) de forma clásica para mejorar la capacidad del kernel de separar los datos, mejorando así el rendimiento general de QML.
#
# ## 💻 Tarea Central: Entrenando el Mapa de Características
#
# Tu tarea es entrenar los parámetros de un mapa de características maximizando la puntuación de Alineamiento del Kernel frente a las etiquetas de los datos de entrenamiento proporcionados.
#
# ### Requisitos
# 1.  **Carga de Datos:** Usa los mismos datos `ad_hoc_data` de 2 qubits para las características y etiquetas que en el Problema 14.
# 2.  **Definir Mapa Parametrizado:** Define un circuito parametrizado `TwoLocal` (Ansatz) para usarlo como Mapa de Características. Esto asegura que el circuito tenga parámetros rotacionales que podamos entrenar.
# 3.  **Instanciar Kernel y Entrenador:** Instancia el `QuantumKernel` y luego el `QuantumKernelTrainer`, suministrándole el kernel, los datos y las etiquetas.
# 4.  **Entrenamiento:** Ejecuta el método `train()` del entrenador. Esto ejecutará el bucle de optimización iterativo.
# 5.  **Verificación:** Imprime la puntuación de alineamiento inicial, la puntuación de alineamiento final optimizada y los parámetros optimizados del mapa de características ($\boldsymbol{\theta}$).
#
# # Solución:

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install qiskit-machine-learning --upgrade
# !pip install qiskit_algorithms

# %%
from qiskit_machine_learning.datasets import ad_hoc_data
from qiskit.circuit.library import TwoLocal
# Nota: Usamos TrainableFidelityQuantumKernel, que está diseñado para esto
from qiskit_machine_learning.kernels import TrainableFidelityQuantumKernel
from qiskit_machine_learning.kernels.algorithms import QuantumKernelTrainer
from qiskit_algorithms.optimizers import COBYLA, SPSA
import numpy as np
import time

# YOUR CODE HERE
raise NotImplementedError()
