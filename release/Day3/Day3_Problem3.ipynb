# %% [markdown]
# # 🤖 Problema 13: Cálculo de una Sola Entrada del Kernel Cuántico
#
# En el Aprendizaje Automático Cuántico (QML), el poder de la mecánica cuántica se aprovecha para calcular la similitud entre dos puntos de datos ($x_i$ y $x_j$) en un espacio de características cuántico de alta dimensión. Esta similitud se mide mediante el Kernel Cuántico $K(x_i, x_j)$.
#
# El valor del kernel se define por la fidelidad (u "overlap") entre los dos estados cuánticos creados al codificar los puntos de datos:
#
# $$k(x_i, x_j)=|\langle \phi(x_i)|\phi(x_j)\rangle|^2$$
#
# Esta fidelidad se mide calculando el valor esperado del operador identidad en el circuito combinado: Circuito = $\phi(x_i)^{\dagger} \cdot \phi(x_j)$.
#
# ## 🎯 Objetivo
#
# Aplicar el concepto de valor esperado (Problema 12) al contexto de QML, calculando una sola entrada de la matriz del Kernel Cuántico, aprovechando específicamente las utilidades de Qiskit Machine Learning.
#
# ## 💻 Tarea Central: Calculando $K(x_A, x_B)$
#
# Utilizarás el `ZZFeatureMap` estándar (nuestro mapa de características $\phi(x)$) y la clase especializada `QuantumKernel` para calcular la entrada del kernel para dos puntos de datos de 2 dimensiones.
#
# ### Requisitos:
#
# 1.  **Definir Puntos de Datos:** Define los dos puntos de datos 2D, $x_A$ y $x_B$, como arrays de NumPy.
# 2.  **Definir Feature Map:** Instancia el `ZZFeatureMap` con 2 qubits.
# 3.  **Instanciar Kernel:** Crea una instancia de `QuantumKernel`, proporcionando el feature map y la primitiva `Estimator` (o `Sampler` según la clase de Kernel).
# 4.  **Calcular Kernel:** Llama al método `evaluate()` del kernel, pasando $x_A$ y $x_B$ en el formato correcto. La salida será una matriz de 1×1 (ya que solo comparamos dos puntos).
# 5.  **Verificar Resultado:** Imprime el valor final único del kernel $k(x_A, x_B)$.
#
# | Componente | Definición | Notas |
# | :--- | :--- | :--- |
# | **Feature Map** | `ZZFeatureMap(feature_dimension=2, reps=1)` | El feature map $\phi(\boldsymbol{x})$ estándar de Qiskit. |
# | **Punto de Dato $\boldsymbol{x}_A$** | `[0.5, 0.5]` | El primer vector de entrada 2D. |
# | **Punto de Dato $\boldsymbol{x}_B$** | `[0.0, 1.0]` | El segundo vector de entrada 2D. |
#
# # Solución:

# %%
# !pip install qiskit
# !pip install qiskit_aer
# !pip install qiskit-machine-learning --upgrade
# !pip install qiskit_algorithms

# %%
# Importaciones Requeridas
from qiskit_aer.primitives import Sampler
from qiskit_machine_learning.kernels import FidelityQuantumKernel
from qiskit.circuit.library import ZZFeatureMap
import numpy as np

# YOUR CODE HERE
raise NotImplementedError()

# --- 5. Verificación de Resultados ---
print(f"\nDatos de Entrenamiento (xA): {training_data}")
print(f"Datos de Prueba (xB): {test_data}")
print("\n--- Resultado del Kernel Cuántico ---")
print(f"Matriz del Kernel (1x1):\n{kernel_matrix}")
print(f"Entrada Única del Kernel k(xA, xB): {kernel_value:.6f}")
