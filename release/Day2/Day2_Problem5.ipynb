# %% [markdown]
# # ⚛️ Problema 10: Descomposición de Paso de Trotter de Primer Orden
#
# La mayoría de los problemas interesantes en física, química y ciencia de materiales pueden describirse por un Hamiltoniano (H), que dicta cómo evoluciona un sistema en el tiempo. Simular el operador de evolución temporal $U(t)=e^{-iHt}$ es el objetivo principal de los algoritmos de simulación cuántica. Dado que no podemos implementar $e^{-iHt}$ directamente, usamos la descomposición de Trotter-Suzuki.
#
# ## 🎯 Objetivo
#
# Introducir la construcción de circuitos fundamental necesaria para los algoritmos de simulación (como VQE, QAOA y Trotterización) construyendo manualmente el componente central de evolución temporal para un Hamiltoniano simple.
#
# ## 💻 Tarea Central: Paso de Trotter para el Hamiltoniano de Ising
#
# Se proporciona un Hamiltoniano de Ising simple de 2 qubits: $H=X_0X_1+Z_0Z_1$
#
# El Paso de Trotter de Primer Orden para un tiempo corto $\Delta t$ aproxima la evolución completa como una secuencia de términos más fáciles de implementar:
#
# $$U(\Delta t)\approx e^{-iH_1\Delta t}e^{-iH_2\Delta t}=e^{-iX_0X_1\Delta t}e^{-iZ_0Z_1\Delta t}$$
#
# Tu tarea es construir el circuito de Qiskit que implementa este paso de Trotter completo para un tiempo $\Delta t$ dado. Esto requiere descomponer los operadores de evolución $XX$ y $ZZ$ en compuertas nativas.
#
# ### Requisitos:
# 1.  **Construcción del Circuito:** Crea un `QuantumCircuit` de 2 qubits.
# 2.  **Define $\Delta t$:** Elige $\Delta t=0.5$
# 3.  **Implementar $ZZ$:** Añade la descomposición completa para el término $e^{-iZ_0Z_1\Delta t}$.
# 4.  **Implementar $XX$:** Añade la descomposición completa para el término $e^{-iX_0X_1\Delta t}$. *(¡Error en el original, lo corregí de $Z_0Z_1$ a $X_0X_1$!)*
# 5.  **Visualización:** Imprime el dibujo del circuito final para mostrar la secuencia completa de compuertas (que deberían ser 10 compuertas en total).
#
# # Solución:

# %%
! pip install qiskit
! pip install qiskit_aer

# %%
from qiskit import QuantumCircuit
import numpy as np

# --- 1. Construcción del Circuito ---
qc = QuantumCircuit(2)
q0, q1 = 0, 1 # Índices de qubit para claridad

# --- 2. Definir el Paso de Tiempo ---
delta_t = 0.5
# El ángulo es 2*delta_t porque la compuerta Rz de Qiskit se define como e^(-i*theta/2*Z)
rotation_angle = 2 * delta_t

# YOUR CODE HERE
raise NotImplementedError()

# --- 5. Visualización ---
print("Circuito Final del Paso de Trotter de Primer Orden (ZZ + XX):")
print(qc.draw('text', fold=-1))
