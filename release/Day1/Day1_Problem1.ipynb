# %% [markdown]
# # ⚛️ Problema 1: Representación de Estados con Clases (Fundamentos de Computación Cuántica)
#
# Este problema está diseñado para construir una base sólida sobre cómo se representan matemáticamente los estados y las operaciones cuánticas, antes de pasar a librerías complejas de programación cuántica como Qiskit.
#
# ## 🎯 Objetivo
#
# * Entender e implementar los conceptos fundamentales de vectores de estado cuántico y compuertas cuánticas (matrices) usando principios estándar de Programación Orientada a Objetos (POO) en Python.
#
# ## 💻 Tarea Central: Definir la Clase Qubit
#
# Tu tarea es definir una clase de Python, `Qubit`, que encapsule el estado de un solo bit cuántico y permita la aplicación de compuertas cuánticas estándar como $R_x$, $R_y$, $R_z$ y $H$.
#
# ### Requisitos:
# 1.  **Definición de la Clase:** Crea una clase llamada `Qubit`.
# 2.  **Inicialización (`__init__`):**
#     * El constructor debe inicializar el vector de estado del qubit al estado $|0\rangle$.
#     * El vector de estado debe almacenarse como un atributo (ej: `self.state`).
# 3.  **Aplicación de Compuerta (`apply_gate`):**
#     * Implementa un método `apply_gate(matrix)` que acepte una matriz de compuerta 2×2 (como un array de NumPy).
#     * Este método debe realizar la multiplicación de matrices de la compuerta de entrada con el vector de estado actual del qubit: $|\psi_{nuevo}\rangle = M|\psi_{actual}\rangle$
#
# ## Solución:

# %%
import numpy as np

# YOUR CODE HERE
raise NotImplementedError()

# --- Prueba de Ejemplo ---
print("\n--- Probando la Clase Qubit ---")
q = Qubit()

# 1. Aplicar compuerta Pauli X (NOT) para voltear |0> a |1>
q.apply_gate(GATE_X)

# 2. Aplicar compuerta Hadamard para crear superposición
q.apply_gate(GATE_H)

# El resultado debería ser el estado de superposición (~[0.707 0.707])
